# %% [markdown]
# # Getting Started with EDA
#
# 1. Use `os.listdir()` to check available files in your folder.
# 2. Use `pandas.read_excel()` to load Excel files, or `pandas.read_csv()` for CSV files.
# 3. Use `df.head()` to preview your data.
#
# You can now proceed to explore and clean your data!

# %%
import pandas as pd

df = pd.read_excel("C:/codeclean/LDM_VD_0525.xlsx")
df.head()
# Out:
#                         _id    transaction_ref transaction_type  \
# 0  683b358b2b4b3d744e1df689  CC1101972749288DL          EXPRESS
# 1  683b358ae79f34e906dd9d6d  CL0511972749262CL           NORMAL
# 2  683b35872b4b3d744e1df687  CC10319727491A5FL           NORMAL
# 3  683b3570e79f34e906dd9d67  CF1481972748BD90L           NORMAL
# 4  683b3566e79f34e906dd9d65  CC03319727489A0AL           NORMAL
#
#    transaction_fee      transaction_fee_until  customer_id  \
# 0              0.0  2024-08-17T23:59:59+07:00            0
# 1              0.0  1901-10-28T23:59:59+06:42            0
# 2              0.0  2024-08-13T23:59:59+07:00            0
# 3              0.0  2024-09-25T23:59:59+07:00            0
# 4              0.0  2024-08-17T23:59:59+07:00            0
#
#   customer_phone_number                 branch_id branch_code  \
# 0             622831610  66c04f5c4509cdb22c2366fc       CC110
# 1             622747322  671f70c48fc72aba8aaeaeaf       CL051
# ...

# %%
import os
print(os.listdir("C:/codeclean"))
# Out:
# ['.git', 'codeclean', 'daily-report-laundromat-1748839222.csv', 'LDM_VD_0525.xlsx', 'payment-kbank-income-report-1748841176.csv', '~$LDM_VD_0525.xlsx']
